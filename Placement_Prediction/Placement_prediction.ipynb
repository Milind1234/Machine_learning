# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.8 MB 9.8 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.8 MB 6.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/12.8 MB 5.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.8 MB 4.8 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/12.8 MB 4.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.8 MB 4.7 MB/s eta 0:00:02
#    -------------------- ------------------- 6.6/12.8 MB 4.8 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.8 MB 4.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.2/12.8 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.8 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.8 MB 5.1 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.8 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 4.8 MB/s  0:00:02
# Installing collected packages: numpy
# Successfully installed numpy-2.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\anaconda3\envs\basic\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda3\envs\basic\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda3\envs\basic\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\basic\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\envs\basic\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\basic\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('Placement_Prediction/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\anaconda3\envs\basic\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in d:\anaconda3\envs\basic\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in d:\anaconda3\envs\basic\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda3\envs\basic\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda3\envs\basic\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 30   7.6  128.0
# 37   8.1  149.0
# 53   8.3  168.0
# 57   6.5  130.0
# 67   5.0  118.0
# ..   ...    ...
# 36   5.7  140.0
# 47   5.2  161.0
# 24   4.7  121.0
# 48   6.6  138.0
# 7    5.0   63.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 30    1
# 37    1
# 53    1
# 57    1
# 67    0
#      ..
# 36    0
# 47    0
# 24    0
# 48    1
# 7     0
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.42307736,  0.12987741],
#        [ 1.86902779,  0.66119409],
#        [ 2.04740796,  1.14190918],
#        [ 0.44198642,  0.180479  ],
#        [-0.89586486, -0.12313053],
#        [ 0.08522608, -1.46407263],
#        [-0.18234417,  0.48408853],
#        [ 0.35279634,  0.45878774],
#        [-2.41209631,  1.52142109],
#        [-1.78776571, -1.21106468],
#        [ 0.44198642, -0.83155277],
#        [-1.16343511, -0.90745515],
#        [-0.80667477, -1.43877183],
#        [-1.2526252 ,  0.58529171],
#        [ 1.33388728,  0.88890124],
#        [-0.98505494,  0.71179568],
#        [-0.003964  , -0.52794324],
#        [ 1.33388728,  0.180479  ],
#        [ 0.88793685,  1.9262338 ],
#        [ 0.08522608,  0.23108059],
#        [ 0.62036659,  1.4961203 ],
#        [ 1.15550711, -1.84358454],
#        [-0.27153426,  1.16720997],
#        [ 1.15550711, -0.93275595],
#        [-0.98505494,  1.85033142],
#        [ 0.26360625, -0.50264245],
#        [ 0.97712694,  0.71179568],
#        [-1.78776571, -0.57854483],
#        [-0.71748469,  0.23108059],
#        [-0.98505494, -1.5652758 ],
#        [ 0.97712694, -1.89418613],
#        [ 1.86902779,  1.09130759],
#        [-0.003964  ,  0.02867423],
#        [ 0.70955668, -0.2749353 ],
#        [-1.07424503,  1.16720997],
#        [-0.53910452,  0.30698297],
#        [ 0.26360625,  0.12987741],
#        [ 0.88793685, -1.48937342],
#        [ 0.70955668,  0.00337344],
#        [ 1.42307736, -0.85685356],
#        [-0.71748469,  2.55875366],
#        [-0.6282946 , -0.22433371],
#        [ 1.15550711, -0.17373212],
#        [ 0.17441617, -0.2496345 ],
#        [-1.07424503,  0.45878774],
#        [ 1.60145753, -0.22433371],
#        [-0.80667477,  0.12987741],
#        [-0.98505494, -0.07252894],
#        [-0.09315409, -0.42674006],
#        [-2.23371614,  2.7864608 ],
#        [ 0.88793685,  1.31901474],
#        [-0.71748469, -0.32553689],
#        [-0.71748469, -0.83155277],
#        [ 0.88793685, -0.2749353 ],
#        [ 0.08522608, -0.50264245],
#        [ 0.35279634, -0.17373212],
#        [ 1.7798377 , -1.10986151],
#        [-0.53910452, -0.22433371],
#        [-1.43100537, -2.04599089],
#        [-0.6282946 , -0.04722815],
#        [-1.43100537,  0.66119409],
#        [-0.27153426,  0.23108059],
#        [-0.003964  , -1.97008851],
#        [ 0.62036659,  0.78769806],
#        [-0.003964  , -1.43877183],
#        [-0.27153426,  0.50938932],
#        [ 0.70955668,  0.45878774],
#        [-0.98505494,  0.28168218],
#        [ 1.33388728, -1.5652758 ],
#        [-0.003964  ,  0.66119409],
#        [ 0.26360625,  0.10457662],
#        [-1.8769558 , -0.35083768],
#        [ 0.70955668, -0.83155277],
#        [-1.07424503,  1.01540521],
#        [ 1.15550711,  0.35758456],
#        [ 0.44198642, -2.17249486],
#        [ 0.08522608,  0.83829965],
#        [ 0.44198642,  0.93950283],
#        [ 0.79874676,  0.40818615],
#        [ 0.79874676, -0.679748  ],
#        [ 0.53117651, -0.07252894],
#        [-1.07424503, -0.2749353 ],
#        [-0.89586486, -0.80625198],
#        [ 0.88793685,  0.40818615],
#        [-0.18234417,  1.09130759],
#        [-0.27153426,  0.43348694],
#        [-0.71748469,  0.96480362],
#        [-1.16343511, -0.04722815],
#        [ 0.53117651,  0.38288535],
#        [-0.89586486, -1.51467421]])

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-1.23423249,  1.70256342],
#        [ 0.18081113, -1.19179439],
#        [-0.76255128,  0.60805836],
#        [-0.60532421,  1.11882739],
#        [ 0.8097194 ,  0.19457868],
#        [-0.36948361, -0.55941369],
#        [ 1.20278707,  0.04864467],
#        [-0.91977835, -1.8971421 ],
#        [-0.36948361,  0.21890101],
#        [ 2.06753595, -0.24322335]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in d:\anaconda3\envs\basic\lib\site-packages (from mlxtend) (1.16.1)
# Requirement already satisfied: numpy>=1.16.2 in d:\anaconda3\envs\basic\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: pandas>=0.24.2 in d:\anaconda3\envs\basic\lib\site-packages (from mlxtend) (2.3.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in d:\anaconda3\envs\basic\lib\site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: matplotlib>=3.0.0 in d:\anaconda3\envs\basic\lib\site-packages (from mlxtend) (3.10.6)
# Requirement already satisfied: joblib>=0.13.2 in d:\anaconda3\envs\basic\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\envs\basic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\basic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\basic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\envs\basic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\basic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda3\envs\basic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\envs\basic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\basic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\basic\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\envs\basic\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\basic\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda3\envs\basic\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ----------------------- ---------------- 0.8/1.4 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 981.5 kB/s  0:00:01
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting  import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values,clf=clf , legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
print(pickle.dump(clf,open('model.pkl','wb')))
# Out:
# None
