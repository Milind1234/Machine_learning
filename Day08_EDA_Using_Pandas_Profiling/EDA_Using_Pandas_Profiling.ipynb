# %%
# Pandas Profiling | Day 22 | CampusX
# ----------------------------------

# 1. Introduction to Pandas Profiling
# - Pandas Profiling is a powerful Python library for automated exploratory data analysis (EDA).
# - Generates comprehensive profile reports on a dataset with a single line of code.
# - Helps quickly understand dataset structure, quality, distributions, and relations.

# 2. Key Features of a Pandas Profiling Report:
#   - Overview:
#     * Dataset dimensions (rows, columns)
#     * Data types of each column
#     * Memory usage
#     * Missing values count and percentage
#     * Duplicate rows percentage
#   - Variables:
#     * Statistical summary per feature (mean, median, mode, min, max, std deviation, quantiles)
#     * Histograms and distribution plots
#     * Number of distinct values
#     * Missing value visualizations
#   - Correlations:
#     * Pearson, Spearman, Kendall Tau, phi_k, and Cramér's V correlations
#     * Helps find linear and categorical feature associations
#   - Missing Values:
#     * Visual representation such as missing value matrices and heatmaps
#   - Sample:
#     * Displays samples of rows from the dataframe (head and tail)
#   - Warnings:
#     * Alerts on potential data issues like high cardinality, skewed distributions, or constant features

# 3. Installation:
# - Use pip: `pip install pandas-profiling`
# - For newer versions, you may install ydata-profiling as it is the maintained fork:
#   `pip install -U ydata-profiling`

# 4. Usage Example:
#   ```
#   import pandas as pd
#   from pandas_profiling import ProfileReport
# df = pd.read_csv('your_dataset.csv')
#   profile = ProfileReport(df, title="Pandas Profiling Report")
#   profile.to_file("your_report.html")
#   ```
# - Open 'your_report.html' in a web browser to explore the interactive report.

# 5. Practical Benefits:
# - Saves time by automating routine EDA tasks.
# - Quickly identifies data quality issues and informs cleaning steps.
# - Provides visual and statistical information necessary for feature engineering.
# - Detects correlations that help in understanding feature interactions.
# - Helps beginners and experts alike to get a comprehensive dataset overview efficiently.

# 6. Tips for Effective Use:
# - For very large datasets, consider using sample subsets to generate the profile faster.
# - Use report parameters to customize output, such as minimal=True for a lighter report.
# - Always interpret warnings and insights to guide your data preprocessing steps effectively.

# -- End of Notes --

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#installing the library 
# !pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in d:\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in d:\anaconda3\lib\site-packages (from sweetviz) (2.2.3)
# Requirement already satisfied: numpy>=1.16.0 in d:\anaconda3\lib\site-packages (from sweetviz) (2.1.3)
# Requirement already satisfied: matplotlib>=3.1.3 in d:\anaconda3\lib\site-packages (from sweetviz) (3.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in d:\anaconda3\lib\site-packages (from sweetviz) (4.67.1)
# Requirement already satisfied: scipy>=1.3.2 in d:\anaconda3\lib\site-packages (from sweetviz) (1.15.3)
# Requirement already satisfied: jinja2>=2.11.1 in d:\anaconda3\lib\site-packages (from sweetviz) (3.1.6)
# Requirement already satisfied: importlib-resources>=1.2.0 in d:\anaconda3\lib\site-packages (from sweetviz) (6.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (24.2)
# Requirement already satisfied: pillow>=8 in d:\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.17.0)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)

# %%
# 2) Load dataset, quick checks, and optional sampling for very large files
import pandas as pd
from IPython.display import IFrame, display, HTML

DATA_PATH = "train.csv"   # change if different

# load
df = pd.read_csv(DATA_PATH)

# basic info
print("Rows, cols:", df.shape)
display(df.head())

# if the dataset is very large, sample to keep the report quick and avoid memory issues
MAX_ROWS_FOR_FULL_REPORT = 200_000   # change if you want
if df.shape[0] > MAX_ROWS_FOR_FULL_REPORT:
    print(f">> Large dataset ({df.shape[0]} rows). Sampling {MAX_ROWS_FOR_FULL_REPORT} rows for profiling.")
    df_sample = df.sample(n=MAX_ROWS_FOR_FULL_REPORT, random_state=42)
else:
    df_sample = df
# Out:
# Rows, cols: (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import sweetviz as sv
import warnings
import numpy as np

# Add this line to handle the missing VisibleDeprecationWarning
# This creates the missing attribute that Sweetviz is looking for
if not hasattr(np, 'VisibleDeprecationWarning'):
    np.VisibleDeprecationWarning = np.VisibleDeprecationWarning = UserWarning

# Suppress related warnings
warnings.filterwarnings('ignore', category=UserWarning)

# Create the report object
# Replace 'df' with your actual DataFrame variable name
report = sv.analyze(df)  

# Save the HTML report to disk
REPORT_FILE = "sweetviz_report.html"
report.show_html(REPORT_FILE, open_browser=False)
print(f"Saved report to {REPORT_FILE}")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweetviz_report.html was generated.
# Saved report to sweetviz_report.html

# %%
# 4) Embed the saved HTML report inside the notebook (iframe)
# (Adjust height if needed)
display(HTML(f'<h3>Sweetviz report</h3>'))
display(IFrame(src=REPORT_FILE, width="100%", height=900))
# Out:
# <h3>Sweetviz report</h3>
#         <iframe
#             width="100%"
#             height="900"
#             src="sweetviz_report.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
# Example: Load your dataframes
df_train = pd.read_csv('train.csv')  # Replace with your actual data loading
df_test = pd.read_csv('train.csv')    # Replace with your actual data loading

# Define TARGET_COLUMN if it's not already defined
TARGET_COLUMN = 'Survived'  # Replace with your actual target column name

# Now compare the dataframes
import sweetviz as sv
from IPython.display import IFrame, display

report_compare = sv.compare([df_train, "Train"], [df_test, "Test"], target_feat=TARGET_COLUMN if TARGET_COLUMN in df_train.columns else None)
report_compare.show_html("sweetviz_compare.html", open_browser=False)
display(IFrame("sweetviz_compare.html", width="100%", height=900))
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweetviz_compare.html was generated.
#         <iframe
#             width="100%"
#             height="900"
#             src="sweetviz_compare.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
# Example: Load your dataframes
df_train = pd.read_csv('train.csv')  # Replace with your actual data loading
df_test = pd.read_csv('train.csv')    # Replace with your actual data loading

# Define TARGET_COLUMN if it's not already defined
TARGET_COLUMN = 'Fare'  # Replace with your actual target column name

# Now compare the dataframes
import sweetviz as sv
from IPython.display import IFrame, display

report_compare = sv.compare([df_train, "Train"], [df_test, "Test"], target_feat=TARGET_COLUMN if TARGET_COLUMN in df_train.columns else None)
report_compare.show_html("sweetviz_compare.html", open_browser=False)
display(IFrame("sweetviz_compare.html", width="100%", height=900))
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweetviz_compare.html was generated.
#         <iframe
#             width="100%"
#             height="900"
#             src="sweetviz_compare.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# %pip install dtale
# Out:
# Requirement already satisfied: dtale in d:\anaconda3\lib\site-packages (3.18.2)
# Requirement already satisfied: lz4 in d:\anaconda3\lib\site-packages (from dtale) (4.3.2)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in d:\anaconda3\lib\site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in d:\anaconda3\lib\site-packages (from dtale) (2025.8.3)
# Requirement already satisfied: cycler in d:\anaconda3\lib\site-packages (from dtale) (0.11.0)
# Requirement already satisfied: dash<=2.18.2 in d:\anaconda3\lib\site-packages (from dtale) (2.18.2)
# Requirement already satisfied: dash-bootstrap-components<=1.7.1 in d:\anaconda3\lib\site-packages (from dtale) (1.7.1)
# Requirement already satisfied: dash_daq<=0.5.0 in d:\anaconda3\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: et_xmlfile in d:\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: Flask in d:\anaconda3\lib\site-packages (from dtale) (3.0.3)
# Requirement already satisfied: Flask-Compress in d:\anaconda3\lib\site-packages (from dtale) (1.18)
# Requirement already satisfied: future>=0.14.0 in d:\anaconda3\lib\site-packages (from dtale) (1.0.0)
# Requirement already satisfied: itsdangerous in d:\anaconda3\lib\site-packages (from dtale) (2.2.0)
# Requirement already satisfied: kaleido in d:\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: matplotlib in d:\anaconda3\lib\site-packages (from dtale) (3.10.0)
# Requirement already satisfied: missingno in d:\anaconda3\lib\site-packages (from dtale) (0.5.2)
# Requirement already satisfied: networkx in d:\anaconda3\lib\site-packages (from dtale) (3.4.2)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from dtale) (2.1.3)
# Requirement already satisfied: openpyxl!=3.2.0b1 in d:\anaconda3\lib\site-packages (from dtale) (3.1.5)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from dtale) (24.2)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from dtale) (2.2.3)
# Requirement already satisfied: pkginfo in d:\anaconda3\lib\site-packages (from dtale) (1.12.0)
# Requirement already satisfied: plotly in d:\anaconda3\lib\site-packages (from dtale) (5.24.1)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from dtale) (2.32.3)
# Requirement already satisfied: scikit-learn in d:\anaconda3\lib\site-packages (from dtale) (1.6.1)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2,<1.16.0 in d:\anaconda3\lib\site-packages (from dtale) (1.15.3)
# Requirement already satisfied: seaborn in d:\anaconda3\lib\site-packages (from dtale) (0.13.2)
# Requirement already satisfied: squarify in d:\anaconda3\lib\site-packages (from dtale) (0.4.4)
# Requirement already satisfied: statsmodels in d:\anaconda3\lib\site-packages (from dtale) (0.14.4)
# Requirement already satisfied: strsimpy in d:\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in d:\anaconda3\lib\site-packages (from dtale) (1.17.0)
# Requirement already satisfied: werkzeug in d:\anaconda3\lib\site-packages (from dtale) (3.0.6)
# Requirement already satisfied: xarray in d:\anaconda3\lib\site-packages (from dtale) (2025.4.0)
# Requirement already satisfied: xlrd in d:\anaconda3\lib\site-packages (from dtale) (2.0.2)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\anaconda3\lib\site-packages (from dash<=2.18.2->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\anaconda3\lib\site-packages (from dash<=2.18.2->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in d:\anaconda3\lib\site-packages (from dash<=2.18.2->dtale) (5.0.0)
# Requirement already satisfied: importlib-metadata in d:\anaconda3\lib\site-packages (from dash<=2.18.2->dtale) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\anaconda3\lib\site-packages (from dash<=2.18.2->dtale) (4.12.2)
# Requirement already satisfied: retrying in d:\anaconda3\lib\site-packages (from dash<=2.18.2->dtale) (1.4.2)
# Requirement already satisfied: nest-asyncio in d:\anaconda3\lib\site-packages (from dash<=2.18.2->dtale) (1.6.0)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from dash<=2.18.2->dtale) (72.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in d:\anaconda3\lib\site-packages (from Flask->dtale) (3.1.6)
# Requirement already satisfied: click>=8.1.3 in d:\anaconda3\lib\site-packages (from Flask->dtale) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in d:\anaconda3\lib\site-packages (from Flask->dtale) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda3\lib\site-packages (from werkzeug->dtale) (3.0.2)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\lib\site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.5)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click>=8.1.3->Flask->dtale) (0.4.6)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda3\lib\site-packages (from plotly->dtale) (9.0.0)
# Requirement already satisfied: brotli in d:\anaconda3\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: pyzstd in d:\anaconda3\lib\site-packages (from Flask-Compress->dtale) (0.17.0)
# Requirement already satisfied: zipp>=3.20 in d:\anaconda3\lib\site-packages (from importlib-metadata->dash<=2.18.2->dtale) (3.21.0)
# Requirement already satisfied: choreographer>=1.0.10 in d:\anaconda3\lib\site-packages (from kaleido->dtale) (1.1.0)
# Requirement already satisfied: logistro>=1.0.8 in d:\anaconda3\lib\site-packages (from kaleido->dtale) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in d:\anaconda3\lib\site-packages (from kaleido->dtale) (3.11.3)
# Requirement already satisfied: pytest-timeout>=2.4.0 in d:\anaconda3\lib\site-packages (from kaleido->dtale) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in d:\anaconda3\lib\site-packages (from choreographer>=1.0.10->kaleido->dtale) (3.20.1)
# Requirement already satisfied: pytest>=7.0.0 in d:\anaconda3\lib\site-packages (from pytest-timeout>=2.4.0->kaleido->dtale) (8.3.4)
# Requirement already satisfied: iniconfig in d:\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido->dtale) (1.1.1)
# Requirement already satisfied: pluggy<2,>=1.5 in d:\anaconda3\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido->dtale) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib->dtale) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\lib\site-packages (from matplotlib->dtale) (1.4.8)
# Requirement already satisfied: pillow>=8 in d:\anaconda3\lib\site-packages (from matplotlib->dtale) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib->dtale) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\lib\site-packages (from pandas->dtale) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests->dtale) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests->dtale) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->dtale) (2.3.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda3\lib\site-packages (from scikit-learn->dtale) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda3\lib\site-packages (from scikit-learn->dtale) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\anaconda3\lib\site-packages (from statsmodels->dtale) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtale
import pandas as pd

df = pd.read_csv("train.csv")
d = dtale.show(df)
d.open_browser()  # Opens interactive UI in browser
# Out:
# D:\anaconda3\Lib\site-packages\kaleido\_sync_server.py:11: UserWarning:
#
#
#
# Warning: You have Plotly version 5.24.1, which is not compatible with this version of Kaleido (1.1.0).
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.

# %%
# %pip install autoviz
# Out:
# Requirement already satisfied: autoviz in d:\anaconda3\lib\site-packages (0.1.905)
# Requirement already satisfied: xlrd in d:\anaconda3\lib\site-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in d:\anaconda3\lib\site-packages (from autoviz) (1.9.4)
# Requirement already satisfied: emoji in d:\anaconda3\lib\site-packages (from autoviz) (2.14.1)
# Requirement already satisfied: pyamg in d:\anaconda3\lib\site-packages (from autoviz) (5.3.0)
# Requirement already satisfied: scikit-learn in d:\anaconda3\lib\site-packages (from autoviz) (1.6.1)
# Requirement already satisfied: statsmodels in d:\anaconda3\lib\site-packages (from autoviz) (0.14.4)
# Requirement already satisfied: nltk in d:\anaconda3\lib\site-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in d:\anaconda3\lib\site-packages (from autoviz) (0.19.0)
# Requirement already satisfied: xgboost<1.7,>=0.82 in d:\anaconda3\lib\site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: fsspec>=0.8.3 in d:\anaconda3\lib\site-packages (from autoviz) (2025.3.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\anaconda3\lib\site-packages (from autoviz) (4.12.2)
# Requirement already satisfied: pandas-dq>=1.29 in d:\anaconda3\lib\site-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in d:\anaconda3\lib\site-packages (from autoviz) (2.1.3)
# Requirement already satisfied: hvplot>=0.9.2 in d:\anaconda3\lib\site-packages (from autoviz) (0.11.3)
# Requirement already satisfied: holoviews>=1.16.0 in d:\anaconda3\lib\site-packages (from autoviz) (1.20.2)
# Requirement already satisfied: panel>=1.4.0 in d:\anaconda3\lib\site-packages (from autoviz) (1.7.0)
# Requirement already satisfied: pandas>=2.0 in d:\anaconda3\lib\site-packages (from autoviz) (2.2.3)
# Requirement already satisfied: matplotlib>3.7.4 in d:\anaconda3\lib\site-packages (from autoviz) (3.10.0)
# Requirement already satisfied: seaborn>0.12.2 in d:\anaconda3\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from xgboost<1.7,>=0.82->autoviz) (1.15.3)
# Requirement already satisfied: bokeh>=3.1 in d:\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.6.2)
# Requirement already satisfied: colorcet in d:\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (24.2)
# Requirement already satisfied: param<3.0,>=2.0 in d:\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (2.2.0)
# Requirement already satisfied: pyviz-comms>=2.1 in d:\anaconda3\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: Jinja2>=2.9 in d:\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in d:\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (1.3.1)
# Requirement already satisfied: pillow>=7.1.0 in d:\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in d:\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in d:\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in d:\anaconda3\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\lib\site-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: bleach in d:\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (6.2.0)
# Requirement already satisfied: linkify-it-py in d:\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.0.0)
# Requirement already satisfied: markdown in d:\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (3.8)
# Requirement already satisfied: markdown-it-py in d:\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in d:\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (0.3.0)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from panel>=1.4.0->autoviz) (4.67.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>3.7.4->autoviz) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda3\lib\site-packages (from scikit-learn->autoviz) (3.5.0)
# Requirement already satisfied: webencodings in d:\anaconda3\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in d:\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.0)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk->autoviz) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\lib\site-packages (from nltk->autoviz) (2024.11.6)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click->nltk->autoviz) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in d:\anaconda3\lib\site-packages (from statsmodels->autoviz) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install nltk
import nltk
nltk.download('words')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# Requirement already satisfied: nltk in d:\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in d:\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package words to C:\Users\milind
# [nltk_data]     chavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\milind
# [nltk_data]     chavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\milind
# [nltk_data]     chavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\milind
# [nltk_data]     chavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\milind
# [nltk_data]     chavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\milind chavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

df = AV.AutoViz("train.csv")  # pass CSV file path
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (891, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  1
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     12 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['PassengerId']
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_609e4_row0_col0, #T_609e4_row0_col2, #T_609e4_row0_col3, #T_609e4_row0_col4, #T_609e4_row0_col5, #T_609e4_row1_col0, #T_609e4_row1_col2, #T_609e4_row1_col3, #T_609e4_row1_col4, #T_609e4_row1_col5, #T_609e4_row2_col0, #T_609e4_row2_col2, #T_609e4_row2_col3, #T_609e4_row2_col4, #T_609e4_row2_col5, #T_609e4_row3_col0, #T_609e4_row3_col2, #T_609e4_row3_col3, #T_609e4_row3_col4, #T_609e4_row3_col5, #T_609e4_row4_col0, #T_609e4_row4_col2, #T_609e4_row4_col3, #T_609e4_row4_col4, #T_609e4_row4_col5, #T_609e4_row5_col0, #T_609e4_row5_col2, #T_609e4_row5_col3, #T_609e4_row5_col4, #T_609e4_row5_col5, #T_609e4_row6_col0, #T_609e4_row6_col2, #T_609e4_row6_col3, #T_609e4_row6_col4, #T_609e4_row6_col5, #T_609e4_row7_col0, #T_609e4_row7_col2, #T_609e4_row7_col3, #T_609e4_row7_col4, #T_609e4_row7_col5, #T_609e4_row8_col0, #T_609e4_row8_col2, #T_609e4_row8_col3, #T_609e4_row8_col4, #T_609e4_row8_col5, #T_609e4_row9_col0, #T_609e4_row9_col2, #T_609e4_row9_col3, #T_609e4_row9_col4, #T_609e4_row9_col5, #T_609e4_row10_col0, #T_609e4_row10_col2, #T_609e4_row10_col3, #T_609e4_row10_col4, #T_609e4_row10_col5, #T_609e4_row11_col0, #T_609e4_row11_col2, #T_609e4_row11_col3, #T_609e4_row11_col4, #T_609e4_row11_col5 {
#   font-family: Segoe UI;
# }
# #T_609e4_row0_col1, #T_609e4_row1_col1, #T_609e4_row2_col1, #T_609e4_row3_col1, #T_609e4_row4_col1, #T_609e4_row6_col1, #T_609e4_row7_col1, #T_609e4_row8_col1, #T_609e4_row9_col1, #T_609e4_row11_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_609e4_row5_col1 {
#   background-color: #fcb99f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_609e4_row10_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_609e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_609e4_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_609e4_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_609e4_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_609e4_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_609e4_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_609e4_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_609e4_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_609e4_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_609e4_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_609e4_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_609e4_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_609e4_row0_col4" class="data row0 col4" >891.000000</td>
#       <td id="T_609e4_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_609e4_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_609e4_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_609e4_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_609e4_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_609e4_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_609e4_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_609e4_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_609e4_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_609e4_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_609e4_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_609e4_row2_col4" class="data row2 col4" >3.000000</td>
#       <td id="T_609e4_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row3" class="row_heading level0 row3" >Name</th>
#       <td id="T_609e4_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_609e4_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_609e4_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_609e4_row3_col3" class="data row3 col3" ></td>
#       <td id="T_609e4_row3_col4" class="data row3 col4" ></td>
#       <td id="T_609e4_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row4" class="row_heading level0 row4" >Sex</th>
#       <td id="T_609e4_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_609e4_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_609e4_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_609e4_row4_col3" class="data row4 col3" ></td>
#       <td id="T_609e4_row4_col4" class="data row4 col4" ></td>
#       <td id="T_609e4_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row5" class="row_heading level0 row5" >Age</th>
#       <td id="T_609e4_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_609e4_row5_col1" class="data row5 col1" >19.865320</td>
#       <td id="T_609e4_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_609e4_row5_col3" class="data row5 col3" >0.420000</td>
#       <td id="T_609e4_row5_col4" class="data row5 col4" >80.000000</td>
#       <td id="T_609e4_row5_col5" class="data row5 col5" >177 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 11 outliers greater than upper bound (64.81) or lower than lower bound(-6.69). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row6" class="row_heading level0 row6" >SibSp</th>
#       <td id="T_609e4_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_609e4_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_609e4_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_609e4_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_609e4_row6_col4" class="data row6 col4" >8.000000</td>
#       <td id="T_609e4_row6_col5" class="data row6 col5" >Column has 46 outliers greater than upper bound (2.50) or lower than lower bound(-1.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row7" class="row_heading level0 row7" >Parch</th>
#       <td id="T_609e4_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_609e4_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_609e4_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_609e4_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_609e4_row7_col4" class="data row7 col4" >6.000000</td>
#       <td id="T_609e4_row7_col5" class="data row7 col5" >Column has 213 outliers greater than upper bound (0.00) or lower than lower bound(0.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row8" class="row_heading level0 row8" >Ticket</th>
#       <td id="T_609e4_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_609e4_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_609e4_row8_col2" class="data row8 col2" >76</td>
#       <td id="T_609e4_row8_col3" class="data row8 col3" ></td>
#       <td id="T_609e4_row8_col4" class="data row8 col4" ></td>
#       <td id="T_609e4_row8_col5" class="data row8 col5" >Possible high cardinality column with 681 unique values: Use hash encoding or text embedding to reduce dimension.</td>
#     </tr>
#     <tr>
#       <th id="T_609e4_level0_row9" class="row_heading level0 row9" >Fare</th>
#       <td id="T_609e4_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_609e4_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_609e4_row9_col2" class="data row9 col2" >NA</td>
#       <td id="T_609e4_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_609e4_row9_col4" class="data row9 col4" >512.329200</td>
#       <td id="T_609e4_row9_col5" class="data
# Number of All Scatter Plots = 3
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\milind
# [nltk_data]    |     chavan\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# All Plots done
# Time to run AutoViz = 28 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %%
# !pip install lux-api
# Out:
# Requirement already satisfied: lux-api in d:\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: scipy>=1.3.3 in d:\anaconda3\lib\site-packages (from lux-api) (1.15.3)
# Requirement already satisfied: altair>=4.0.0 in d:\anaconda3\lib\site-packages (from lux-api) (5.5.0)
# Requirement already satisfied: numpy>=1.16.5 in d:\anaconda3\lib\site-packages (from lux-api) (2.1.3)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from lux-api) (2.2.3)
# Requirement already satisfied: scikit-learn>=0.22 in d:\anaconda3\lib\site-packages (from lux-api) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in d:\anaconda3\lib\site-packages (from lux-api) (3.10.0)
# Requirement already satisfied: lux-widget>=0.1.4 in d:\anaconda3\lib\site-packages (from lux-api) (0.1.11)
# Requirement already satisfied: autopep8>=1.5 in d:\anaconda3\lib\site-packages (from lux-api) (2.0.4)
# Requirement already satisfied: iso3166 in d:\anaconda3\lib\site-packages (from lux-api) (2.1.1)
# Requirement already satisfied: psutil>=5.9.0 in d:\anaconda3\lib\site-packages (from lux-api) (5.9.0)
# Requirement already satisfied: sh in d:\anaconda3\lib\site-packages (from lux-api) (2.2.2)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in d:\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in d:\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (1.31.0)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api) (4.12.2)
# Requirement already satisfied: pycodestyle>=2.10.0 in d:\anaconda3\lib\site-packages (from autopep8>=1.5->lux-api) (2.12.1)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.22.3)
# Requirement already satisfied: notebook>=4.0.0 in d:\anaconda3\lib\site-packages (from lux-widget>=0.1.4->lux-api) (7.3.2)
# Requirement already satisfied: ipywidgets>=7.5.0 in d:\anaconda3\lib\site-packages (from lux-widget>=0.1.4->lux-api) (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in d:\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.13)
# Requirement already satisfied: decorator in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.19.1)
# Requirement already satisfied: stack-data in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.4.6)
# Requirement already satisfied: wcwidth in d:\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (1.4.8)
# Requirement already satisfied: pillow>=8 in d:\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api) (2.9.0.post0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in d:\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.3.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in d:\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in d:\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.5.1)
# Requirement already satisfied: anyio>=3.1.0 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.2.5)
# Requirement already satisfied: setuptools>=40.8.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (72.1.0)
# Requirement already satisfied: babel>=2.10 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.9.25)
# Requirement already satisfied: requests>=2.31 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.32.3)
# Requirement already satisfied: idna>=2.8 in d:\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.7)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (21.2.0)
# Requirement already satisfied: certifi in d:\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in d:\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.16.0)
# Requirement already satisfied: debugpy>=1.6.5 in d:\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.8.11)
# Requirement already satisfied: nest-asyncio in d:\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2->altair>=4.0.0->lux-api) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.3.7)
# Requirement already satisfied: pywin32>=300 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (308)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.0.2)
# Requirement already satisfied: rfc3339-validator in d:\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.1.1)
# Requirement already satisfied: fqdn in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.1)
# Requirement already satisfied: isoduration in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.1)
# Requirement already satisfied: uri-template in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.2.0)
# Requirement already satisfied: defusedxml in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.0)
# Requirement already satisfied: webencodings in d:\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.20.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->lux-api) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.3.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda3\lib\site-packages (from scikit-learn>=0.22->lux-api) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda3\lib\site-packages (from scikit-learn>=0.22->lux-api) (3.5.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.17.1)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.21)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in d:\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->lux-api) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\lib\site-packages (from pandas->lux-api) (2025.2)
# Requirement already satisfied: executing in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.0)
# Requirement already satisfied: pure-eval in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.2)

# %%
# %pip install lux-api lux-widget --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import lux
from IPython.display import display

print("lux version:", lux.__version__)

df = pd.read_csv("train.csv")
# set lux to show recommendations by default
lux.config.default_display = "widget"  

# show the DataFrame (this should render the widget with recommendations)
display(df)
# Out:
# lux version: 0.5.1
#      PassengerId  Survived  Pclass  \
# 0          1          0        3
# 1          2          1        1
# 2          3          1        3
# 3          4          1        1
# 4          5          0        3
# ..           ...       ...     ...
# 886      887          0        2
# 887      888          1        1
# 888      889          0        3
# 889      890          1        1
# 890      891          0        3
#
#                             Name                           Sex     Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0    1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0    1
# 2                                 Heikkinen, Miss. Laina  female  26.0    0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1
# 4                               Allen, Mr. William Henry    male  35.0    0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0    0
# 887                         Graham, Miss. Margaret Edith  female  19.0    0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN    1
# 889                                Behr, Mr. Karl Howell    male  26.0    0
# 890                                  Dooley, Mr. Patrick    male  32.0    0
#
#      Parch       Ticket        Fare   Cabin Embarked
# 0      0           A/5 21171   7.2500   NaN     S
# 1      0            PC 17599  71.2833   C85     C
# 2      0    STON/O2. 3101282   7.9250   NaN     S
# 3      0              113803  53.1000  C123     S
# 4      0              373450   8.0500   NaN     S
# ..     ...               ...      ...   ...      ...
# 886    0              211536  13.0000   NaN     S
# 887    0              112053  30.0000   B42     S
# 888    2          W./C. 6607  23.4500   NaN     S
# 889    0              111369  30.0000  C148     C
# 890    0              370376   7.7500   NaN     Q
#
# [891 rows x 12 columns]

# %%
# %pip install dataprep

# %%
from dataprep.eda import create_report
import pandas as pd

df = pd.read_csv("train.csv")
create_report(df).show_browser()
